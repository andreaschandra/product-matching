# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
data_path = "../data/raw"

# %%
d_train = pd.read_csv(os.path.join(data_path, "new_training_set.csv"),
                      usecols=["title_1", "image_1", "title_2", "image_2", "Label"])

# %%
d_test = pd.read_csv(os.path.join(data_path, "new_test_sample.csv"),
                     names=["pair_index", "title_1", "image_1", "title_2", "image_2"],skiprows=1)

# %%
d_test['Label'] = 1

# %%
d_test
# Out:
#      pair_index                                            title_1  \
# 0             0   12.12 SUPER PROMO !! Sandal Jepit Pantai Fashion
# 1             1  Damai fashion jakarta - long dress JUMBO wanit...
# 2             2                        My Baby Minyak Telon 145 ML
# 3             3  Creative Waterborne Marker Very Fine Double - ...
# 4             4  Goblin♛ COD Tas Ransel Anak Sekolah Karakter K...
# ..          ...                                                ...
# 202         202  Handsock Jempol Wanita / Handsock Jempol Polos...
# 203         203  Case IPhone Full Cover Case Soft-touch Silikon...
# 204         204  YOONA LONG DRESS PLISKET // GAMIS ALEXA SLEEVE...
# 205         205  Tempat Pensil Model Unicorn Ukuran 17 * 21cm u...
# 206         206   BOLT Makanan Kucing Repack 1kg - netto 1000 gram
#
#                                   image_1  \
# 0    83d1798fee1c90c2845204d9261169bb.jpg
# 1    126868769ca4a4694d36d28960f9de8a.jpg
# 2    86aee3dc281911f5f9d50fea17b978f0.jpg
# 3    40ef98354335cf4780937da703ed6d65.jpg
# 4    c28512df97d0fc1d61fd30de966e01c3.jpg
# ..                                    ...
# 202  3a5a47af6705ba090bcc3447a6ae4588.jpg
# 203  6bac0d6d8ea250012a452a3e2857593c.jpg
# 204  97be9c6f042dd6bb4d8d26e6082b2f8e.jpg
# 205  5b08e9ef401d7176c22588529ed2aa1a.jpg
# 206  d21c84efbda5409ebdf2bedbf53105af.jpg
#
#                                                title_2  \
# 0    Clarisse CRAZY OFFER Beli 5 Dapet 12 POLKA SUM...
# 1    [VIP] kasih fashion jakarta - long dress JUMBO...
# 2    My Baby Minyak Telon Plus 145 Ml 4btl kemasan ...
# 3               SOMETHINC BROW WIZ Retractable Eyebrow
# 4                               TAS KARAKTER ANAK LUCU
# ..                                                 ...
# 202  Handsock Jempol Wanita / Handsock Jempol Polos...
# 203  iphone Case Original Silicone Liquid Case for ...
# 204  YOONA LONG DRESS PLISKET // GAMIS ALEXA SLEEVE...
# 205  Tempat Pensil Model Unicorn Bahan Plush untuk ...
# 206  BOLT Makanan Kucing Bentuk Donat Repack 1kg - ...
#
#                                   image_2  Label
# 0    caba83a8a7f9def9c4d268b6c34da7f4.jpg      1
# 1    7fdfe855a7be9c87238757c43b712b81.jpg      1
# 2    0ec544d3d4169df76ae156e76c724f0c.jpg      1
# 3    9cf798e5f940429f14b4af0fd48992a4.jpg      1
# 4    a4c09a46d8b1adda43a2433d40bba583.jpg      1
# ..                                    ...    ...
# 202  eebfbbbf8e962231f5eb93b21b098193.jpg      1
# 203  e790c3cc8cdc4af86637f1c453624c0a.jpg      1
# 204  e535b80abd8b8c59ef773519435d4d6e.jpg      1
# 205  ec0d572a23bfa37267db279bb0a45078.jpg      1
# 206  6c3d211ef059b8cd13558d47e032d2ef.jpg      1
#
# [207 rows x 6 columns]

# %%
# d_test[["pair_index", "title_1", "title_2", "Label"]].to_excel("../data/dummy_label.xlsx", index=False)

# %%
img_path1 = os.path.join(data_path, "sample_img", d_test.loc[1, 'image_1'])
img_path2 = os.path.join(data_path, "sample_img", d_test.loc[1, 'image_2'])

# %%
img1 = cv2.imread(img_path1)

# %%
plt.imshow(img1)

# %%
img2 = cv2.imread(img_path2)

# %%
plt.imshow(img2)

# %%
e
